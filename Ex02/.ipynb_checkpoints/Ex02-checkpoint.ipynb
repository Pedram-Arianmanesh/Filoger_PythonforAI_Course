# %% [markdown]
# ![ex2.png](attachment:7bffbf19-7e34-4362-95d0-e5244afed98c.png)

# %% [markdown]
# # 1

# %%
NList = [1, 2, [3, 4], [5, [100, 200, ['Hello']], 23, 11], 1, 7]
print(*NList[3][1][2])
# Out:
# Hello

# %% [markdown]
# # 2

# %%
d = {'k1':[1, 2, 3, {'tricky':['oh', 'man', 'inception', {'target': [1, 2, 3, 'Hello']}]}]}
print(d['k1'][3]['tricky'][3]['target'][3])
# Out:
# Hello

# %% [markdown]
# # 3

# %%
'''
The key difference between tuples and lists is that while tuples are immutable objects, lists are mutable. This means tuples cannot be changed while lists can be modified.
'''
tuple_sample = (1, 2, 3)
list_sample = [1, 2, 3]
print(tuple_sample)
print(list_sample)
try:
    tuple_sample[2] = 4
except TypeError as error:
    print(error)
list_sample[2] = 4 
print('changed list:', list_sample)
# Out:
# (1, 2, 3)
# [1, 2, 3]
# 'tuple' object does not support item assignment
# changed list: [1, 2, 4]

# %% [markdown]
# # 4

# %%
'''
Elements in set are unique and it doesn`t alowes duplicates
'''
set_example = {1, 2, 3, 3, 4, 2}
print(set_example)
# Out:
# {1, 2, 3, 4}

# %% [markdown]
# # 5

# %%
'''
Lists are ordered collections of items, whereas the dictionary is an unordered collection of data in a key: value pair form. 
'''
# Out:
# '\nLists are ordered collections of items, whereas the dictionary is an unordered collection of data in a key: value pair form. \n'
