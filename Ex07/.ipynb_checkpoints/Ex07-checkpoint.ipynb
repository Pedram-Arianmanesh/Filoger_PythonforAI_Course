# %% [markdown]
# ![ex7.png](attachment:e9cca5cc-8153-4c25-b38c-b943458a9ee5.png)

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 1

# %%
rand_nums = []
for i in range(5):
    rand_nums.append(np.random.uniform())
rand_nums = np.array(rand_nums)
index_list = ['Pedram', 'Ali', 'Amir', 'Hassan', 'Akbar']
ex1_seri = pd.Series(data=rand_nums, index=index_list)
ex1_seri
# Out:
# Pedram    0.272406
# Ali       0.910604
# Amir      0.859575
# Hassan    0.871155
# Akbar     0.740949
# dtype: float64

# %% [markdown]
# # 2

# %%
pd.Series(index_list)
# Out:
# 0    Pedram
# 1       Ali
# 2      Amir
# 3    Hassan
# 4     Akbar
# dtype: object

# %% [markdown]
# # 3

# %%
ex1_seri[0]
# Out:
# /tmp/ipykernel_7246/3429965797.py:1: FutureWarning: Series.__getitem__ treating keys as positions is deprecated. In a future version, integer keys will always be treated as labels (consistent with DataFrame behavior). To access a value by position, use `ser.iloc[pos]`
#   ex1_seri[0]
# 0.27240640648647696
